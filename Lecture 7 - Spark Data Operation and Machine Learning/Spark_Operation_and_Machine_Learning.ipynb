# %% [markdown]
# ## Spark data operation
# - The purpose is to learn about spark data operations and practice using them with pyspark

# %% [markdown]
# ### Set up Spark

# %%
# !wget https://github.com/ppkgtmm/big-data/raw/main/setup_spark_colab.sh
# Out:
# --2022-03-05 17:41:09--  https://github.com/ppkgtmm/big-data/raw/main/setup_spark_colab.sh
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ppkgtmm/big-data/main/setup_spark_colab.sh [following]
# --2022-03-05 17:41:09--  https://raw.githubusercontent.com/ppkgtmm/big-data/main/setup_spark_colab.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 511 [text/plain]
# Saving to: ‘setup_spark_colab.sh’
#
# setup_spark_colab.s 100%[===================>]     511  --.-KB/s    in 0s
#
# 2022-03-05 17:41:09 (16.4 MB/s) - ‘setup_spark_colab.sh’ saved [511/511]

# %%
# %%bash
# chmod +x ./setup_spark_colab.sh
# ./setup_spark_colab.sh &> /dev/null

# %% [markdown]
# ### Import libraries

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# ### Create session
# - Spark session is an entry point to spark applicaion

# %%
spark = SparkSession \
    .builder \
    .appName("Lecture 7 Spark") \
    .getOrCreate()

# %% [markdown]
# #### Note: All .toPandas() here are unnecessary in the real use. We use them here in order to display the result only.

# %% [markdown]
# ### Spark SQL

# %%
spark.sql('SHOW DATABASES').show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %% [markdown]
# ### Create Spark DataFrame from a file

# %%
df = (
    spark
    .read
    .format('csv')
    .option('inferSchema','true')
    .option('delimiter',',')
    .option('header','true')
    .load('Superstore.csv')
)

# %%
df.limit(5).toPandas()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase    261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...    731.94        3
# 2  Self-Adhesive Address Labels for Typewriters b...     14.62        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System    22.368        2
#
#   Discount    Profit
# 0        0   41.9136
# 1        0  219.5820
# 2        0    6.8714
# 3     0.45 -383.0310
# 4      0.2    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Rename columns

# %%
new_names = [c.replace(' ','_') for c in df.columns]
print(new_names)

df = df.toDF(*new_names)
df.limit(5).toPandas()
# Out:
# ['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State', 'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category', 'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit']
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product_Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase    261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...    731.94        3
# 2  Self-Adhesive Address Labels for Typewriters b...     14.62        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System    22.368        2
#
#   Discount    Profit
# 0        0   41.9136
# 1        0  219.5820
# 2        0    6.8714
# 3     0.45 -383.0310
# 4      0.2    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Write DataFrame to Hive table

# %%
df.write.format('parquet').mode('overwrite').saveAsTable('superstore')

# %%
spark.sql('SHOW TABLES').show()
# Out:
# +---------+----------+-----------+
# |namespace| tableName|isTemporary|
# +---------+----------+-----------+
# |  default|superstore|      false|
# +---------+----------+-----------+

# %%
df = spark.sql('SELECT * FROM superstore')

# %%
df.limit(5).toPandas()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product_Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase    261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...    731.94        3
# 2  Self-Adhesive Address Labels for Typewriters b...     14.62        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System    22.368        2
#
#   Discount    Profit
# 0        0   41.9136
# 1        0  219.5820
# 2        0    6.8714
# 3     0.45 -383.0310
# 4      0.2    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Print DataFrame structure

# %%
(df.count(), len(df.columns))
# Out:
# (9994, 21)

# %%
df.printSchema()
# Out:
# root
#  |-- Row_ID: integer (nullable = true)
#  |-- Order_ID: string (nullable = true)
#  |-- Order_Date: timestamp (nullable = true)
#  |-- Ship_Date: timestamp (nullable = true)
#  |-- Ship_Mode: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Customer_Name: string (nullable = true)
#  |-- Segment: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Postal_Code: integer (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Product_ID: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Sub-Category: string (nullable = true)
#  |-- Product_Name: string (nullable = true)
#  |-- Sales: string (nullable = true)
#  |-- Quantity: string (nullable = true)
#  |-- Discount: string (nullable = true)
#  |-- Profit: double (nullable = true)

# %% [markdown]
# ### Show DataFrame

# %%
df.limit(1).toPandas()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer_Name   Segment        Country       City  ... Postal_Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product_ID   Category Sub-Category                       Product_Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales Quantity Discount   Profit
# 0  261.96        2        0  41.9136
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Select columns

# %%
df.select('Sales').toPandas()
# Out:
#          Sales
# 0       261.96
# 1       731.94
# 2        14.62
# 3     957.5775
# 4       22.368
# ...        ...
# 9989    25.248
# 9990     91.96
# 9991   258.576
# 9992      29.6
# 9993    243.16
#
# [9994 rows x 1 columns]

# %%
df.select(['Sales','Profit']).toPandas()
# Out:
#          Sales    Profit
# 0       261.96   41.9136
# 1       731.94  219.5820
# 2        14.62    6.8714
# 3     957.5775 -383.0310
# 4       22.368    2.5164
# ...        ...       ...
# 9989    25.248    4.1028
# 9990     91.96   15.6332
# 9991   258.576   19.3932
# 9992      29.6   13.3200
# 9993    243.16   72.9480
#
# [9994 rows x 2 columns]

# %% [markdown]
# ### Sorting

# %%
df.orderBy('Order_ID').limit(5).toPandas()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0    2718  CA-2014-100006 2014-09-07 2014-09-13  Standard Class    DK-13375
# 1    6289  CA-2014-100090 2014-07-08 2014-07-12  Standard Class    EB-13705
# 2    6288  CA-2014-100090 2014-07-08 2014-07-12  Standard Class    EB-13705
# 3    9515  CA-2014-100293 2014-03-14 2014-03-18  Standard Class    NF-18475
# 4    3084  CA-2014-100328 2014-01-28 2014-02-03  Standard Class    JC-15340
#
#       Customer_Name      Segment        Country           City  ...  \
# 0       Dennis Kane     Consumer  United States  New York City  ...
# 1        Ed Braxton    Corporate  United States  San Francisco  ...
# 2        Ed Braxton    Corporate  United States  San Francisco  ...
# 3  Neil Französisch  Home Office  United States   Jacksonville  ...
# 4   Jasper Cacioppo     Consumer  United States  New York City  ...
#
#   Postal_Code  Region       Product_ID         Category Sub-Category  \
# 0       10024    East  TEC-PH-10002075       Technology       Phones
# 1       94122    West  OFF-BI-10001597  Office Supplies      Binders
# 2       94122    West  FUR-TA-10003715        Furniture       Tables
# 3       32216   South  OFF-PA-10000176  Office Supplies        Paper
# 4       10024    East  OFF-BI-10000343  Office Supplies      Binders
#
#                                         Product_Name         Sales Quantity  \
# 0                                  AT&T EL51110 DECT        377.97        3
# 1   Wilson Jones Ledger-Size, Piano-Hinge Binder, 2"         Blue"  196.704
# 2            Hon 2111 Invitation Series Corner Table       502.488        3
# 3                                         Xerox 1887        91.056        6
# 4  "Pressboard Covers with Storage Hooks, 9 1/2""...   Light Blue"    3.928
#
#   Discount    Profit
# 0        0  109.6113
# 1        6    0.2000
# 2      0.2  -87.9354
# 3      0.2   31.8696
# 4        1    0.2000
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Filtering

# %%
df[df.Ship_Mode == 'Second Class'].limit(5).toPandas()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
# 3      18  CA-2014-167164 2014-05-13 2014-05-15  Second Class    AG-10270
# 4      19  CA-2014-143336 2014-08-27 2014-09-01  Second Class    ZD-21925
#
#         Customer_Name    Segment        Country           City  ...  \
# 0         Claire Gute   Consumer  United States      Henderson  ...
# 1         Claire Gute   Consumer  United States      Henderson  ...
# 2     Darrin Van Huff  Corporate  United States    Los Angeles  ...
# 3     Alejandro Grove   Consumer  United States    West Jordan  ...
# 4  Zuschuss Donatelli   Consumer  United States  San Francisco  ...
#
#   Postal_Code  Region       Product_ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       84084    West  OFF-ST-10000107  Office Supplies      Storage
# 4       94109    West  OFF-AR-10003056  Office Supplies          Art
#
#                                         Product_Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62        2
# 3                         Fellowes Super Stor/Drawer    55.5        2
# 4                                         Newell 341    8.56        2
#
#   Discount    Profit
# 0        0   41.9136
# 1        0  219.5820
# 2        0    6.8714
# 3        0    9.9900
# 4        0    2.4824
#
# [5 rows x 21 columns]

# %%
df.filter('Ship_Mode == "Standard Class" and Customer_ID  == "SO-20335"').toPandas()
# Out:
#     Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0        4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 1        5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 2     3374  CA-2015-161718 2015-12-04 2015-12-10  Standard Class    SO-20335
# 3     3375  CA-2015-161718 2015-12-04 2015-12-10  Standard Class    SO-20335
# 4     3376  CA-2015-161718 2015-12-04 2015-12-10  Standard Class    SO-20335
# 5     3377  CA-2015-161718 2015-12-04 2015-12-10  Standard Class    SO-20335
# 6     4623  CA-2017-147228 2017-09-09 2017-09-14  Standard Class    SO-20335
# 7     4624  CA-2017-147228 2017-09-09 2017-09-14  Standard Class    SO-20335
# 8     4625  CA-2017-147228 2017-09-09 2017-09-14  Standard Class    SO-20335
# 9     4626  CA-2017-147228 2017-09-09 2017-09-14  Standard Class    SO-20335
# 10    6980  CA-2017-149076 2017-01-14 2017-01-19  Standard Class    SO-20335
# 11    7122  CA-2017-166926 2017-12-01 2017-12-08  Standard Class    SO-20335
# 12    7123  CA-2017-166926 2017-12-01 2017-12-08  Standard Class    SO-20335
#
#      Customer_Name   Segment        Country             City  ... Postal_Code  \
# 0   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 1   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 2   Sean O'Donnell  Consumer  United States        Hempstead  ...       11550
# 3   Sean O'Donnell  Consumer  United States        Hempstead  ...       11550
# 4   Sean O'Donnell  Consumer  United States        Hempstead  ...       11550
# 5   Sean O'Donnell  Consumer  United States        Hempstead  ...       11550
# 6   Sean O'Donnell  Consumer  United States         Columbia  ...       38401
# 7   Sean O'Donnell  Consumer  United States         Columbia  ...       38401
# 8   Sean O'Donnell  Consumer  United States         Columbia  ...       38401
# 9   Sean O'Donnell  Consumer  United States         Columbia  ...       38401
# 10  Sean O'Donnell  Consumer  United States      Los Angeles  ...       90036
# 11  Sean O'Donnell  Consumer  United States          Seattle  ...       98105
# 12  Sean O'Donnell  Consumer  United States          Seattle  ...       98105
#
#     Region       Product_ID         Category Sub-Category  \
# 0    South  FUR-TA-10000577        Furniture       Tables
# 1    South  OFF-ST-10000760  Office Supplies      Storage
# 2     East  FUR-FU-10002445        Furniture  Furnishings
# 3     East  FUR-CH-10002372        Furniture       Chairs
# 4     East  TEC-PH-10000376       Technology       Phones
# 5     East  FUR-CH-10002965        Furniture       Chairs
# 6    South  OFF-SU-10001225  Office Supplies     Supplies
# 7    South  OFF-PA-10000357  Office Supplies        Paper
# 8    South  OFF-ST-10000046  Office Supplies      Storage
# 9    South  FUR-FU-10000023        Furniture  Furnishings
# 10    West  OFF-PA-10000483  Office Supplies        Paper
# 11    West  OFF-PA-10001593  Office Supplies        Paper
# 12    West  FUR-BO-10002598        Furniture    Bookcases
#
#                                          Product_Name     Sales Quantity  \
# 0       Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 1                      Eldon Fold 'N Roll Cart System    22.368        2
# 2   DAX Two-Tone Rosewood/Black Document Frame, De...     28.44        3
# 3     Office Star - Ergonomically Designed Knee Chair    364.41        5
# 4                           Square Credit Card Reader     39.96        4
# 5   Global Leather Highback Executive Chair with P...   361.764        2
# 6                                      Staple remover     8.832        3
# 7                                          Xerox 1888   177.536        4
# 8                    Fellowes Super Stor/Drawer Files    258.48        2
# 9                         Eldon Wave Desk Accessories    14.136        3
# 10                                           Xerox 19     154.9        5
# 11                                         Xerox 1947     41.86        7
# 12                         Hon Metal Bookcases, Putty    141.96        2
#
#    Discount    Profit
# 0      0.45 -383.0310
# 1       0.2    2.5164
# 2         0   11.3760
# 3       0.1    8.0980
# 4         0   10.3896
# 5       0.1   68.3332
# 6       0.2   -1.9872
# 7       0.2   62.1376
# 8       0.2   -3.2310
# 9       0.2    4.2408
# 10        0   69.7050
# 11        0   18.8370
# 12        0   41.1684
#
# [13 rows x 21 columns]

# %% [markdown]
# ### Add a constant column

# %%
from pyspark.sql.functions import lit

# not mutate original data
df.withColumn('One',lit(1)).limit(5).toPandas()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product_ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product_Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase    261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...    731.94        3
# 2  Self-Adhesive Address Labels for Typewriters b...     14.62        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System    22.368        2
#
#   Discount    Profit One
# 0        0   41.9136   1
# 1        0  219.5820   1
# 2        0    6.8714   1
# 3     0.45 -383.0310   1
# 4      0.2    2.5164   1
#
# [5 rows x 22 columns]

# %%
df.limit(5).toPandas()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product_Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase    261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...    731.94        3
# 2  Self-Adhesive Address Labels for Typewriters b...     14.62        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System    22.368        2
#
#   Discount    Profit
# 0        0   41.9136
# 1        0  219.5820
# 2        0    6.8714
# 3     0.45 -383.0310
# 4      0.2    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Add a column (from other columns)

# %%
df.withColumn('Margin',df['Profit']/df['Sales']).limit(5).toPandas()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product_ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product_Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase    261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...    731.94        3
# 2  Self-Adhesive Address Labels for Typewriters b...     14.62        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System    22.368        2
#
#   Discount    Profit  Margin
# 0        0   41.9136  0.1600
# 1        0  219.5820  0.3000
# 2        0    6.8714  0.4700
# 3     0.45 -383.0310 -0.4000
# 4      0.2    2.5164  0.1125
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Replace/update the column

# %%
df1 = df.withColumn('Unit_Price', df['Sales'] + df['Profit'])

# %%
df1.withColumn('Unit_Price',df1['Unit_Price'] / df1['Quantity'])\
   .select(['Product_ID','Product_Name','Unit_Price']).limit(5).show()
# Out:
# +---------------+--------------------+------------------+
# |     Product_ID|        Product_Name|        Unit_Price|
# +---------------+--------------------+------------------+
# |FUR-BO-10001798|Bush Somerset Col...|          151.9368|
# |FUR-CH-10000454|Hon Deluxe Fabric...|317.17400000000004|
# |OFF-LA-10000240|Self-Adhesive Add...|           10.7457|
# |FUR-TA-10000577|Bretford CR4500 S...|114.90929999999999|
# |OFF-ST-10000760|Eldon Fold 'N Rol...|           12.4422|
# +---------------+--------------------+------------------+

# %% [markdown]
# ### Convert a column data type

# %%
df.withColumn('Postal_Code',df['Postal_Code'].cast('string'))\
  .printSchema()
# Out:
# root
#  |-- Row_ID: integer (nullable = true)
#  |-- Order_ID: string (nullable = true)
#  |-- Order_Date: timestamp (nullable = true)
#  |-- Ship_Date: timestamp (nullable = true)
#  |-- Ship_Mode: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Customer_Name: string (nullable = true)
#  |-- Segment: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Postal_Code: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Product_ID: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Sub-Category: string (nullable = true)
#  |-- Product_Name: string (nullable = true)
#  |-- Sales: string (nullable = true)
#  |-- Quantity: string (nullable = true)
#  |-- Discount: string (nullable = true)
#  |-- Profit: double (nullable = true)

# %% [markdown]
# ### Drop columns

# %%
df.drop('Sales','Discount','Profit').printSchema()
# Out:
# root
#  |-- Row_ID: integer (nullable = true)
#  |-- Order_ID: string (nullable = true)
#  |-- Order_Date: timestamp (nullable = true)
#  |-- Ship_Date: timestamp (nullable = true)
#  |-- Ship_Mode: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Customer_Name: string (nullable = true)
#  |-- Segment: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Postal_Code: integer (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Product_ID: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Sub-Category: string (nullable = true)
#  |-- Product_Name: string (nullable = true)
#  |-- Quantity: string (nullable = true)

# %% [markdown]
# ### Check distribution

# %%
df.describe().toPandas()
# Out:
#   summary              Row_ID        Order_ID       Ship_Mode Customer_ID  \
# 0   count                9994            9994            9994        9994
# 1    mean              4997.5            None            None        None
# 2  stddev  2885.1636290974325            None            None        None
# 3     min                   1  CA-2014-100006     First Class    AA-10315
# 4     max                9994  US-2017-169551  Standard Class    ZD-21925
#
#         Customer_Name      Segment        Country      City    State  \
# 0                9994         9994           9994      9994     9994
# 1                None         None           None      None     None
# 2                None         None           None      None     None
# 3       Aaron Bergman     Consumer  United States  Aberdeen  Alabama
# 4  Zuschuss Donatelli  Home Office  United States      Yuma  Wyoming
#
#           Postal_Code   Region       Product_ID    Category Sub-Category  \
# 0                9994     9994             9994        9994         9994
# 1    55190.3794276566     None             None        None         None
# 2  32063.693350364487     None             None        None         None
# 3                1040  Central  FUR-BO-10000112   Furniture  Accessories
# 4               99301     West  TEC-PH-10004977  Technology       Tables
#
#                            Product_Name               Sales  \
# 0                                  9994                9994
# 1                                  None  234.41818199917006
# 2                                  None   631.7890112674363
# 3  """While you Were Out"" Message Book            10/Pack"
# 4    netTALK DUO VoIP Telephone Service              999.98
#
#              Quantity            Discount              Profit
# 0                9994                9994                9994
# 1   5.828590535392018  0.3155949113492862  28.587912967780834
# 2  25.520975563736403   3.314008629792499   234.3891156047269
# 3        1040 sheets"             30/Box"           -6599.978
# 4              98.352              98.352            8399.976

# %% [markdown]
# ### Check missing data

# %%
df.filter("Sales is NULL").count()
# Out:
# 0

# %%
df.filter(df['Sales'].isNull()).count()
# Out:
# 0

# %% [markdown]
# ### Aggregation

# %%
df.groupBy('Category').agg({'Sales':'sum'}).show()
# Out:
# +---------------+-----------------+
# |       Category|       sum(Sales)|
# +---------------+-----------------+
# |Office Supplies|703502.9280000031|
# |      Furniture|733046.8612999996|
# |     Technology|835900.0669999964|
# +---------------+-----------------+

# %% [markdown]
# ### Customer single view

# %%
df.groupBy('Customer_ID')\
  .agg({'Sales':'sum','Order_ID':'count'}).show()
# Out:
# +-----------+---------------+------------------+
# |Customer_ID|count(Order_ID)|        sum(Sales)|
# +-----------+---------------+------------------+
# |   VW-21775|             18|          6112.702|
# |   PB-19210|              2|           132.738|
# |   RR-19315|              4|           615.932|
# |   EM-13960|              6|           933.704|
# |   MY-17380|             13|2242.6119999999996|
# |   MS-17530|              7|475.65599999999995|
# |   KH-16630|             17|          3918.966|
# |   BD-11500|             10|4408.2970000000005|
# |   SW-20275|              7|           1966.65|
# |   AH-10690|             23| 7888.294000000001|
# |   PH-18790|              2|           729.648|
# |   JF-15490|             15|          1082.918|
# |   JF-15415|             14|          2371.448|
# |   IM-15070|             21| 4930.473999999999|
# |   PW-19240|             12|3878.3149999999996|
# |   JH-15985|             14|          7954.998|
# |   OT-18730|             10|3818.6240000000003|
# |   KM-16225|             19|          2134.248|
# |   NW-18400|             22| 7234.013999999999|
# |   KF-16285|             18|         10604.266|
# +-----------+---------------+------------------+
# only showing top 20 rows
